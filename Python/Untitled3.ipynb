# %%
import pandas as pd
from talib import abstract
import talib
import numpy as np
df  = pd.read_csv("BTCUSDT-1m-data.csv")

list_of_functions = talib.get_functions()
df
# Out:
#                    timestamp      open      high       low     close  \
# 0        2017-08-17 04:00:00   4261.48   4261.48   4261.48   4261.48
# 1        2017-08-17 04:01:00   4261.48   4261.48   4261.48   4261.48
# 2        2017-08-17 04:02:00   4280.56   4280.56   4280.56   4280.56
# 3        2017-08-17 04:03:00   4261.48   4261.48   4261.48   4261.48
# 4        2017-08-17 04:04:00   4261.48   4261.48   4261.48   4261.48
# ...                      ...       ...       ...       ...       ...
# 1898508  2021-04-01 21:25:00  58746.39  58763.62  58736.32  58762.37
# 1898509  2021-04-01 21:26:00  58762.54  58783.75  58737.93  58770.21
# 1898510  2021-04-01 21:27:00  58768.77  58768.98  58706.22  58717.57
# 1898511  2021-04-01 21:28:00  58713.02  58722.21  58696.49  58696.50
# 1898512  2021-04-01 21:29:00  58696.49  58705.89  58686.31  58700.00
#
#             volume     close_time      quote_av  trades  tb_base_av  \
# 0         1.775183  1502942459999  7.564907e+03       3    0.075183
# ...

# %%
data = []
for function in list_of_functions:
    if function=='MAVP':
        pass
    else:
        # or by name
        funcname = abstract.Function(function)
        myString = "abstract."+str(function)+"(df, timeperiod = 14)"
        my_list = eval(myString)
        df1 = pd.DataFrame(my_list)
        if df1.columns.any()==0:
            df1.rename(columns = {0:function}, inplace = True)
        df = pd.concat([df, df1], join = 'outer', axis = 1)
        print(df)
df.to_csv("BTC_Modf_lib.csv")
# Out:
#                    timestamp      open      high       low     close  \
# 0        2017-08-17 04:00:00   4261.48   4261.48   4261.48   4261.48
# 1        2017-08-17 04:01:00   4261.48   4261.48   4261.48   4261.48
# 2        2017-08-17 04:02:00   4280.56   4280.56   4280.56   4280.56
# 3        2017-08-17 04:03:00   4261.48   4261.48   4261.48   4261.48
# 4        2017-08-17 04:04:00   4261.48   4261.48   4261.48   4261.48
# ...                      ...       ...       ...       ...       ...
# 1898508  2021-04-01 21:25:00  58746.39  58763.62  58736.32  58762.37
# 1898509  2021-04-01 21:26:00  58762.54  58783.75  58737.93  58770.21
# 1898510  2021-04-01 21:27:00  58768.77  58768.98  58706.22  58717.57
# 1898511  2021-04-01 21:28:00  58713.02  58722.21  58696.49  58696.50
# 1898512  2021-04-01 21:29:00  58696.49  58705.89  58686.31  58700.00
#
#             volume     close_time      quote_av  trades  tb_base_av  \
# 0         1.775183  1502942459999  7.564907e+03       3    0.075183
# ...
