# %%
import pandas as pd
import ta
df  = pd.read_csv("LTCUSDT-1m-data.csv")

df = ta.add_all_ta_features(
    df, open="open", high="high", low="low", close="close", volume="volume", fillna=True)
print(df)
df.to_csv("LTC_Modf.csv")
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
#                    timestamp    open    high     low   close     volume  \
# 0        2017-12-13 03:32:00  272.00  272.00  272.00  272.00    0.50000
# 1        2017-12-13 03:33:00  272.00  272.00  272.00  272.00    0.00000
# 2        2017-12-13 03:34:00  272.00  272.00  272.00  272.00    0.00000
# 3        2017-12-13 03:35:00  272.00  272.00  272.00  272.00    0.00000
# 4        2017-12-13 03:36:00  272.00  272.00  272.00  272.00    0.00000
# ...                      ...     ...     ...     ...     ...        ...
# 1728990  2021-04-01 20:42:00  201.37  201.65  201.30  201.53  202.51491
# ...

# %%
import pandas as pd

df = pd.read_csv("LTC_Modf.csv")

df = df.iloc[:, 1:]
df.to_csv("LTC_Modf.csv", index=False)
