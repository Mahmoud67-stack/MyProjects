# %%
pip install -c peterjc123 pytorch-cpu
# Out:
# ERROR: Could not find a version that satisfies the requirement pytorch-cpu (from versions: none)
# ERROR: No matching distribution found for pytorch-cpu
