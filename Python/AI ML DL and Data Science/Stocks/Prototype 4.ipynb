# %% [markdown]
# #Importing the Important Libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('AMZN.USUSD_Candlestick_1_M_BID_01.03.2020-10.07.2020.csv')
#dataset['Local time'] = datetime.strptime(dataset['Local time'], full)
dataset.index = dataset['Local time']
dataset = dataset.drop('Local time', axis =1 )
dataset_original = dataset
dataset_original
# Out:
#                               Open      High       Low     Close  Volume
# Local time
# 02.03.2020 18:30:00.000   1903.667  1913.607  1902.578  1906.018  0.2750
# 02.03.2020 18:31:00.000   1905.868  1907.287  1899.998  1905.148  0.2355
# 02.03.2020 18:32:00.000   1905.148  1908.068  1896.007  1896.007  0.2635
# 02.03.2020 18:33:00.000   1896.008  1903.697  1895.007  1895.747  0.2395
# 02.03.2020 18:34:00.000   1895.467  1896.327  1890.737  1891.437  0.2912
# ...                            ...       ...       ...       ...     ...
# 10.07.2020 23:55:00.000   3198.538  3202.898  3198.117  3201.808  0.1975
# 10.07.2020 23:56:00.000   3201.807  3202.388  3200.768  3201.458  0.1415
# 10.07.2020 23:57:00.000   3200.778  3204.018  3200.777  3202.198  0.1390
# 10.07.2020 23:58:00.000   3201.598  3206.208  3201.597  3204.798  0.2650
# 10.07.2020 23:59:00.000   3204.838  3205.388  3201.598  3201.997  0.3158
#
# [35808 rows x 5 columns]

# %%
dataset['percentage change'] = 100*(dataset['Close']-dataset['Open'])/dataset['Open']

# %%
dataset
# Out:
#                               Open      High  ...  Volume  percentage change
# Local time                                    ...
# 02.03.2020 18:30:00.000   1903.667  1913.607  ...  0.2750           0.123498
# 02.03.2020 18:31:00.000   1905.868  1907.287  ...  0.2355          -0.037778
# 02.03.2020 18:32:00.000   1905.148  1908.068  ...  0.2635          -0.479805
# 02.03.2020 18:33:00.000   1896.008  1903.697  ...  0.2395          -0.013766
# 02.03.2020 18:34:00.000   1895.467  1896.327  ...  0.2912          -0.212613
# ...                            ...       ...  ...     ...                ...
# 10.07.2020 23:55:00.000   3198.538  3202.898  ...  0.1975           0.102234
# 10.07.2020 23:56:00.000   3201.807  3202.388  ...  0.1415          -0.010900
# 10.07.2020 23:57:00.000   3200.778  3204.018  ...  0.1390           0.044364
# 10.07.2020 23:58:00.000   3201.598  3206.208  ...  0.2650           0.099950
# 10.07.2020 23:59:00.000   3204.838  3205.388  ...  0.3158          -0.088647
#
# [35808 rows x 6 columns]

# %%
dataset
# Out:
#                               Open      High  ...  Volume  percentage change
# Local time                                    ...
# 02.03.2020 18:30:00.000   1903.667  1913.607  ...  0.2750           0.123498
# 02.03.2020 18:31:00.000   1905.868  1907.287  ...  0.2355          -0.037778
# 02.03.2020 18:32:00.000   1905.148  1908.068  ...  0.2635          -0.479805
# 02.03.2020 18:33:00.000   1896.008  1903.697  ...  0.2395          -0.013766
# 02.03.2020 18:34:00.000   1895.467  1896.327  ...  0.2912          -0.212613
# ...                            ...       ...  ...     ...                ...
# 10.07.2020 23:55:00.000   3198.538  3202.898  ...  0.1975           0.102234
# 10.07.2020 23:56:00.000   3201.807  3202.388  ...  0.1415          -0.010900
# 10.07.2020 23:57:00.000   3200.778  3204.018  ...  0.1390           0.044364
# 10.07.2020 23:58:00.000   3201.598  3206.208  ...  0.2650           0.099950
# 10.07.2020 23:59:00.000   3204.838  3205.388  ...  0.3158          -0.088647
#
# [35808 rows x 6 columns]

# %%
def rsiFunc(close,n=14):
    deltas = np.diff(close)
    seed = deltas[:n+1]
    up = seed[seed >= 0].sum()/n
    down = -seed[seed < 0].sum()/n
    rs = up/down
    rsi = np.zeros_like(close)
    rsi[:n] = 100. - 100./(1.+rs)

    for i in range(n, len(close)):
        delta = deltas[i-1]  # cause the diff is 1 shorter

        if delta > 0:
            upval = delta
            downval = 0.
        else:
            upval = 0.
            downval = -delta

        up = (up*(n-1) + upval)/n
        down = (down*(n-1) + downval)/n

        rs = up/down
        rsi[i] = 100. - 100./(1.+rs)

    return rsi

dataset['RSI'] = rsiFunc(dataset['Close'])

# %%
dataset
# Out:
#                               Open      High  ...  percentage change        RSI
# Local time                                    ...
# 02.03.2020 18:30:00.000   1903.667  1913.607  ...           0.123498  48.043407
# 02.03.2020 18:31:00.000   1905.868  1907.287  ...          -0.037778  48.043407
# 02.03.2020 18:32:00.000   1905.148  1908.068  ...          -0.479805  48.043407
# 02.03.2020 18:33:00.000   1896.008  1903.697  ...          -0.013766  48.043407
# 02.03.2020 18:34:00.000   1895.467  1896.327  ...          -0.212613  48.043407
# ...                            ...       ...  ...                ...        ...
# 10.07.2020 23:55:00.000   3198.538  3202.898  ...           0.102234  53.207285
# 10.07.2020 23:56:00.000   3201.807  3202.388  ...          -0.010900  52.292104
# 10.07.2020 23:57:00.000   3200.778  3204.018  ...           0.044364  54.090109
# 10.07.2020 23:58:00.000   3201.598  3206.208  ...           0.099950  59.819890
# 10.07.2020 23:59:00.000   3204.838  3205.388  ...          -0.088647  52.253760
#
# [35808 rows x 7 columns]

# %%
Typical_Price = (dataset['High']+dataset['Low']+dataset['Close'])/3
Money_Flow = dataset['Volume']*Typical_Price


def MFIfunc(Typical_Price,n=14):
    deltas = np.diff(Typical_Price)
    seed = deltas[:n+1]
    Positive_Money_Flow = seed[seed >= 0].sum()/n
    Negative_Money_Flow = -seed[seed < 0].sum()/n
    Money_Ratio = Positive_Money_Flow/Negative_Money_Flow
    MFI = np.zeros_like(Typical_Price)
    MFI[:n] = 100. - 100./(1.+Money_Ratio)

    for i in range(n, len(Typical_Price)):
        delta = deltas[i-1]  # cause the diff is 1 shorter

        if delta > 0:
            upval = delta
            downval = 0
        else:
            downval = -delta
            upval = 0

        Positive_Money_Flow = (Positive_Money_Flow*(n-1) + upval)/n
        Negative_Money_Flow = (Negative_Money_Flow*(n-1) + downval)/n

        Money_Ratio = Positive_Money_Flow/Negative_Money_Flow
        MFI[i] = 100. - 100./(1.+Money_Ratio)

    return MFI

dataset['MFI'] = MFIfunc(Typical_Price)

# %%
dataset
# Out:
#                               Open      High  ...        RSI        MFI
# Local time                                    ...
# 02.03.2020 18:30:00.000   1903.667  1913.607  ...  48.043407  46.119447
# 02.03.2020 18:31:00.000   1905.868  1907.287  ...  48.043407  46.119447
# 02.03.2020 18:32:00.000   1905.148  1908.068  ...  48.043407  46.119447
# 02.03.2020 18:33:00.000   1896.008  1903.697  ...  48.043407  46.119447
# 02.03.2020 18:34:00.000   1895.467  1896.327  ...  48.043407  46.119447
# ...                            ...       ...  ...        ...        ...
# 10.07.2020 23:55:00.000   3198.538  3202.898  ...  53.207285  51.946866
# 10.07.2020 23:56:00.000   3201.807  3202.388  ...  52.292104  53.841971
# 10.07.2020 23:57:00.000   3200.778  3204.018  ...  54.090109  56.306918
# 10.07.2020 23:58:00.000   3201.598  3206.208  ...  59.819890  61.524801
# 10.07.2020 23:59:00.000   3204.838  3205.388  ...  52.253760  56.810266
#
# [35808 rows x 8 columns]

# %%
dataset['EMA'] = dataset['Close'].ewm(com=0.4).mean()
dataset
# Out:
#                               Open      High  ...        MFI          EMA
# Local time                                    ...
# 02.03.2020 18:30:00.000   1903.667  1913.607  ...  46.119447  1906.018000
# 02.03.2020 18:31:00.000   1905.868  1907.287  ...  46.119447  1905.341333
# 02.03.2020 18:32:00.000   1905.148  1908.068  ...  46.119447  1898.514731
# 02.03.2020 18:33:00.000   1896.008  1903.697  ...  46.119447  1896.524518
# 02.03.2020 18:34:00.000   1895.467  1896.327  ...  46.119447  1892.883644
# ...                            ...       ...  ...        ...          ...
# 10.07.2020 23:55:00.000   3198.538  3202.898  ...  51.946866  3201.049177
# 10.07.2020 23:56:00.000   3201.807  3202.388  ...  53.841971  3201.341194
# 10.07.2020 23:57:00.000   3200.778  3204.018  ...  56.306918  3201.953198
# 10.07.2020 23:58:00.000   3201.598  3206.208  ...  61.524801  3203.985199
# 10.07.2020 23:59:00.000   3204.838  3205.388  ...  56.810266  3202.565057
#
# [35808 rows x 9 columns]

# %%
dataset['%K'] = ((dataset['Close']-np.min(dataset['Low']))/np.max(dataset['High']-np.min(dataset['Low'])))*100
dataset
# Out:
#                               Open      High  ...          EMA         %K
# Local time                                    ...
# 02.03.2020 18:30:00.000   1903.667  1913.607  ...  1906.018000  17.705038
# 02.03.2020 18:31:00.000   1905.868  1907.287  ...  1905.341333  17.650224
# 02.03.2020 18:32:00.000   1905.148  1908.068  ...  1898.514731  17.074297
# 02.03.2020 18:33:00.000   1896.008  1903.697  ...  1896.524518  17.057916
# 02.03.2020 18:34:00.000   1895.467  1896.327  ...  1892.883644  16.786365
# ...                            ...       ...  ...          ...        ...
# 10.07.2020 23:55:00.000   3198.538  3202.898  ...  3201.049177  99.346010
# 10.07.2020 23:56:00.000   3201.807  3202.388  ...  3201.341194  99.323959
# 10.07.2020 23:57:00.000   3200.778  3204.018  ...  3201.953198  99.370582
# 10.07.2020 23:58:00.000   3201.598  3206.208  ...  3203.985199  99.534395
# 10.07.2020 23:59:00.000   3204.838  3205.388  ...  3202.565057  99.357918
#
# [35808 rows x 10 columns]

# %%
MACD = (0.075*dataset['EMA']) - (0.15*dataset['EMA'])
dataset['Signal Line'] = 0.2*MACD.ewm(com=0.4).mean()
dataset
# Out:
#                               Open      High  ...         %K  Signal Line
# Local time                                    ...
# 02.03.2020 18:30:00.000   1903.667  1913.607  ...  17.705038   -28.590270
# 02.03.2020 18:31:00.000   1905.868  1907.287  ...  17.650224   -28.582376
# 02.03.2020 18:32:00.000   1905.148  1908.068  ...  17.074297   -28.505837
# 02.03.2020 18:33:00.000   1896.008  1903.697  ...  17.057916   -28.464153
# 02.03.2020 18:34:00.000   1895.467  1896.327  ...  16.786365   -28.413415
# ...                            ...       ...  ...        ...          ...
# 10.07.2020 23:55:00.000   3198.538  3202.898  ...  99.346010   -48.009820
# 10.07.2020 23:56:00.000   3201.807  3202.388  ...  99.323959   -48.017176
# 10.07.2020 23:57:00.000   3200.778  3204.018  ...  99.370582   -48.025834
# 10.07.2020 23:58:00.000   3201.598  3206.208  ...  99.534395   -48.050080
# 10.07.2020 23:59:00.000   3204.838  3205.388  ...  99.357918   -48.041791
#
# [35808 rows x 11 columns]

# %%
dataset['percentage_pred'] = dataset['percentage change'].shift(-390)

# %%
dataset.loc[dataset['percentage_pred']<0,'Invest'] = int(0)
dataset.loc[dataset['percentage_pred']>=0, 'Invest'] = int(1)
dataset
# Out:
#                               Open      High  ...  percentage_pred  Invest
# Local time                                    ...
# 02.03.2020 18:30:00.000   1903.667  1913.607  ...        -0.511861     0.0
# 02.03.2020 18:31:00.000   1905.868  1907.287  ...        -0.000510     0.0
# 02.03.2020 18:32:00.000   1905.148  1908.068  ...        -0.161116     0.0
# 02.03.2020 18:33:00.000   1896.008  1903.697  ...         0.371150     1.0
# 02.03.2020 18:34:00.000   1895.467  1896.327  ...        -0.397803     0.0
# ...                            ...       ...  ...              ...     ...
# 10.07.2020 23:55:00.000   3198.538  3202.898  ...              NaN     NaN
# 10.07.2020 23:56:00.000   3201.807  3202.388  ...              NaN     NaN
# 10.07.2020 23:57:00.000   3200.778  3204.018  ...              NaN     NaN
# 10.07.2020 23:58:00.000   3201.598  3206.208  ...              NaN     NaN
# 10.07.2020 23:59:00.000   3204.838  3205.388  ...              NaN     NaN
#
# [35808 rows x 13 columns]

# %%
X = dataset[['percentage change','RSI','MFI','EMA','%K','Signal Line']].values
y = dataset[['Invest']].values
print(X)
print(y)
# Out:
# [[ 1.23498490e-01  4.80434074e+01  4.61194474e+01  1.90601800e+03
#    1.77050381e+01 -2.85902700e+01]
#  [-3.77780623e-02  4.80434074e+01  4.61194474e+01  1.90534133e+03
#    1.76502239e+01 -2.85823756e+01]
#  [-4.79805243e-01  4.80434074e+01  4.61194474e+01  1.89851473e+03
#    1.70742971e+01 -2.85058371e+01]
#  ...
#  [ 4.43642140e-02  5.40901086e+01  5.63069179e+01  3.20195320e+03
#    9.93705822e+01 -4.80258344e+01]
#  [ 9.99500874e-02  5.98198901e+01  6.15248012e+01  3.20398520e+03
#    9.95343946e+01 -4.80500798e+01]
#  [-8.86472265e-02  5.22537603e+01  5.68102659e+01  3.20256506e+03
#    9.93579182e+01 -4.80417913e+01]]
# [[ 0.]
#  [ 0.]
#  [ 0.]
#  ...
#  [nan]
#  [nan]
#  [nan]]

# %%
X = X[:-390]
print(X)
y = y[:-390]
# Out:
# [[ 1.23498490e-01  4.80434074e+01  4.61194474e+01  1.90601800e+03
#    1.77050381e+01 -2.85902700e+01]
#  [-3.77780623e-02  4.80434074e+01  4.61194474e+01  1.90534133e+03
#    1.76502239e+01 -2.85823756e+01]
#  [-4.79805243e-01  4.80434074e+01  4.61194474e+01  1.89851473e+03
#    1.70742971e+01 -2.85058371e+01]
#  ...
#  [ 7.70796650e-02  5.23619911e+01  5.11673303e+01  3.18163173e+03
#    9.81155268e+01 -4.77206510e+01]
#  [-1.57120151e-02  5.16776540e+01  5.24080606e+01  3.18173621e+03
#    9.80840244e+01 -4.77245025e+01]
#  [ 5.09213303e-02  5.32820523e+01  5.34715925e+01  3.18263749e+03
#    9.81608903e+01 -4.77352595e+01]]

# %%
print(y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [1.]
#  [1.]
#  [0.]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.15,random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from xgboost import XGBRFClassifier
classifier = XGBRFClassifier()
classifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# XGBRFClassifier(base_score=0.5, colsample_bylevel=1, colsample_bynode=0.8,
#                 colsample_bytree=1, gamma=0, learning_rate=1, max_delta_step=0,
#                 max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#                 n_jobs=1, nthread=None, objective='binary:logistic',
#                 random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                 seed=None, silent=None, subsample=0.8, verbosity=1)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[ 610 2008]
#  [ 604 2091]]
# 0.5083756822887258

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy: 50.80 %
# Standard Deviation: 0.72 %
