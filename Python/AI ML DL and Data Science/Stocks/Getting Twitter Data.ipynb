# %% [markdown]
# # importing machine learning libraries

# %%
import numpy as np
import pandas as pd
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
import matplotlib.pyplot as mlpt
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# #importing library to fetch data from twitter

# %%
import tweepy
import csv
import pandas as pd
import random
import numpy as np
import pandas as pd

# %% [markdown]
# #setting up consumer key and access token

# %%
consumer_key    = '3jmA1BqasLHfItBXj3KnAIGFB'
consumer_secret = 'imyEeVTctFZuK62QHmL1I0AUAMudg5HKJDfkx0oR7oFbFinbvA'

access_token  = '265857263-pF1DRxgIcxUbxEEFtLwLODPzD3aMl6d4zOKlMnme'
access_token_secret = 'uUFoOOGeNJfOYD3atlcmPtaxxniXxQzAU4ESJLopA1lbC'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %% [markdown]
# #Fetching tweets aapl in extended mode (means entire tweet will come and not just few words + link)

# %%
fetch_tweets=tweepy.Cursor(api.search, q="aapl",count=100, lang ="en",since="2020-01-20", tweet_mode="extended").items()
data=pd.DataFrame(data=[[tweet_info.created_at.date(),tweet_info.full_text]for tweet_info in fetch_tweets],columns=['Date','Tweets'])

# %%
data
# Out:
#              Date                                             Tweets
# 0      2020-07-26  $ES - Major Support &amp; Resistance levels to...
# 1      2020-07-26  Discord https://t.co/VJCTdWfIjw\n\nTo get advi...
# 2      2020-07-26  RT @AppleTerminal: News:\n\n@Apple Q3 revenue ...
# 3      2020-07-26  $SPY $SPX $QQQ $ES_F $NQ_F $RTY_F $ZB_F $GC_F ...
# 4      2020-07-26  $ES - Major Support &amp; Resistance levels to...
# ...           ...                                                ...
# 27450  2020-07-18  $AAPL TA update and thoughts  #WeightyRelentle...
# 27451  2020-07-18  @s01181969 @hmeisler Direct through AAPL or AMZN?
# 27452  2020-07-18  $AAPL $AMZN $BTC $ETH $FB $GOOG $MSFT $QQQ $SP...
# 27453  2020-07-18  RT @IdeasPrime: Apple | $AAPL\n\nAPPLE POTENTI...
# 27454  2020-07-18  @Convertbond Last time it was $AAPL that broke...
#
# [27455 rows x 2 columns]
